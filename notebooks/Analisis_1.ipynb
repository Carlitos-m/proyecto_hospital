# %%
import pandas as pd

# %%
from src.hospital_app.data_loader import  dfs, nuevas_llaves

# %%
dfs['Hosffa']
# Out:
#             num_fac area     folio  ext cve_ing_num cve_ing_mbo     f_fac  \
# 0                 1  CZM         2    0                     2.0  20241003
# 1                 2  CZM        11    0                     2.0  20241003
# 2                 3  CZM         3    1       11718           1  20241003
# 3                 4  CZM         5    1       11721           1  20241003
# 4                 5  CZM        29    0                     2.0  20241003
# ...             ...  ...       ...  ...         ...         ...       ...
# 25389  TCA        6  CZM     48452    N       59655           1  20250812
# 25390  TCA        7  CZM     46505    N       57920           1  20250922
# 25391  TCA        8  CZM     46505    N       57920           1  20250930
# 25392  TCA        9  CZM     48574    N       59771           1  20251110
# 25393  TCA       10  CZM     47894    N       59194           1  20260308
#
#         h_fac u_fac     f_act  ... veces_imp status                ciudad  \
# ...
